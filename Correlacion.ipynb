# %%
import matplotlib.pyplot as plt
import numpy as np


N = 1000

alturas = np.random.normal(145, 5, N)
pesos = np.random.normal(100, 5, N)

alturas.sort()
print(alturas)


plt.scatter(alturas, pesos) 
plt.xlabel("Altura (cms)")
plt.ylabel("Peso (kgs)")
plt.show()
# Out:
# [127.50765477 130.02299121 131.61784836 131.86179454 132.00134801
#  132.23349198 132.68729864 132.80515126 133.02525052 133.08187655
#  133.39715784 133.48199305 133.56125423 133.87951549 133.88892561
#  133.91271939 134.5569777  134.61980886 134.66658852 134.72203615
#  134.84520754 135.13205694 135.30868551 135.54508076 135.59326348
#  135.67184304 135.67284436 135.69742344 135.72006865 135.82311549
#  135.83637117 135.86278499 136.01356974 136.02982087 136.19921656
#  136.22808196 136.2894421  136.36171183 136.44590572 136.46171874
#  136.64672997 136.64926172 136.76583911 136.76716109 136.83764214
#  136.93825877 137.02141566 137.0578244  137.18682705 137.27972486
#  137.29369977 137.30076152 137.33499415 137.33601382 137.35410602
#  137.36252877 137.53803062 137.55175825 137.555183   137.55546113
#  137.55934765 137.562892   137.64122828 137.66625778 137.7558235
#  137.80452914 137.83378061 137.90664378 137.94408728 138.02804586
# ...
